# %%
import polars as pl
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import util

# %%
RAM_REF_MAPPIGN = "/storage2/tbrekalo/HG002-simulated/chr19-sample-ram-ref.paf"
TB_RAM_LCSKPP_REF_MAPPIGN = "/storage2/tbrekalo/HG002-simulated/chr19-sample-tb-ram-lcskpp-ref.paf"
TB_RAM_REF_MAPPING = "/storage2/tbrekalo/HG002-simulated/chr19-sample-tb-ram-ref.paf"
TB_RAM_AI_REF_MAPPIGN = "/storage2/tbrekalo/HG002-simulated/chr19-sample-tb-ram-ai-ref.tsv"
MINIMAP2_REF_MAPPIGN = "/storage2/tbrekalo/HG002-simulated/chr19-sample-ovlps-minimap2-ref.paf"
READ_ORIGINS = "/storage2/tbrekalo/HG002-simulated/chr19-read-origins.csv"

# %%
df_origins = util.load_origins_df(READ_ORIGINS)
MIN_RATIO=0.875

# %%
def create_df_ai_ram(
    input_path: pl.DataFrame, df_origins: pl.DataFrame
) -> pl.DataFrame:
    return (
        util.create_annotated_ref_overlaps(
            pl.read_csv(
                input_path,
                has_header=False,
                new_columns=util.RAM_OVERLAP_AI_COLUMNS,
                separator="\t",
            ),
            df_origins,
        )
        .select(
            *util.RAM_OVERLAP_AI_COLUMNS,
            pl.col("ratio"),
            (pl.col("ratio") > MIN_RATIO).cast(pl.Int64).alias("label"),
        )
        .with_columns(
            pl.when(pl.col("strand") == "+")
            .then(pl.lit(1))
            .otherwise(pl.lit(0))
            .alias("strand"),
            pl.min_horizontal(
                pl.col("query-matches"),
                pl.col("target-matches"),
            ).alias("n-residue-matches"),
        )
    )


df_tb_ram_ai = create_df_ai_ram(TB_RAM_AI_REF_MAPPIGN, df_origins)

# %%
def load_ref_df(path: str, df_origins: pl.DataFrame, min_ratio: float) -> pl.DataFrame:
    return (
        util.create_annotated_ref_overlaps(
            util.load_paf_df(path),
            df_origins,
        )
        .with_columns(
            pl.when(pl.col("strand") == "+").then(pl.lit(1)).otherwise(pl.lit(0)).alias("strand")
        )
        .drop("origin-start", "origin-end", "origin-strand")
        .with_columns((pl.col("ratio") > min_ratio).alias("label").cast(pl.Int64))
    )

# %%
df_minimap2 = load_ref_df(MINIMAP2_REF_MAPPIGN, df_origins, MIN_RATIO)
df_tb_ram_lcskpp = load_ref_df(TB_RAM_LCSKPP_REF_MAPPIGN, df_origins, MIN_RATIO)
df_tb_ram = load_ref_df(TB_RAM_REF_MAPPING, df_origins, MIN_RATIO)
df_ram = load_ref_df(RAM_REF_MAPPIGN, df_origins, MIN_RATIO)

# %%
print(f'minimap2: {df_minimap2.select(pl.col("label").value_counts())}')
# print(f'ram: {df_ram.select(pl.col("label").value_counts())}')
print(f'tb-ram-lcskpp: {df_tb_ram_lcskpp.select(pl.col("label").value_counts())}')
print(f'tb-ram: {df_tb_ram.select(pl.col("label").value_counts())}')
# Out:
# minimap2: shape: (2, 1)
# ┌───────────┐
# │ label     │
# │ ---       │
# │ struct[2] │
# ╞═══════════╡
# │ {1,1119}  │
# │ {0,154}   │
# └───────────┘
# tb-ram-lcskpp: shape: (2, 1)
# ┌───────────┐
# │ label     │
# │ ---       │
# │ struct[2] │
# ╞═══════════╡
# │ {0,62}    │
# │ {1,1055}  │
# └───────────┘
# tb-ram: shape: (2, 1)
# ┌───────────┐
# │ label     │
# │ ---       │
# │ struct[2] │
# ╞═══════════╡
# │ {0,9}     │
# │ {1,1108}  │
# └───────────┘

# %%
dfs = {
    "minimap2": df_minimap2,
    "tb-ram-lcsk": df_tb_ram_lcskpp,
    "tb-ram": df_tb_ram.select(*util.PAF_COLUMNS, "label"),
    "ram": df_ram,
}


def overlap_metrics(df_in: pl.DataFrame, source: str) -> pl.DataFrame:
    return df_in.select(*util.PAF_COLUMNS, "label").with_columns(
        pl.max_horizontal(
            (pl.col("query-end") - pl.col("query-start")),
            (pl.col("target-end") - pl.col("target-start")),
        ).alias("overlap-length"),
        pl.lit(source).alias("source"),
    )


df_overlaps = pl.concat([
    overlap_metrics(df, source) for source, df in dfs.items()
])

# %%
df_overlaps.group_by("source", "label").agg(
    pl.struct(["query-name", "target-name"]).n_unique().alias("n-unique-pairs"),
    pl.col("overlap-length").mean().alias("overlap-length-mean"),
    pl.col("overlap-length").std().alias("overlap-length-std"),
    pl.col("overlap-length").quantile(0.25).alias("overlap-length-q25"),
    pl.col("overlap-length").median().alias("overlap-length-median"),
    pl.col("overlap-length").quantile(0.75).alias("overlap-length-q75"),
).sort(by=["source", "label"])
# Out:
# shape: (8, 8)
# ┌────────────┬───────┬────────────┬────────────┬────────────┬────────────┬────────────┬────────────┐
# │ source     ┆ label ┆ n-unique-p ┆ overlap-le ┆ overlap-le ┆ overlap-le ┆ overlap-le ┆ overlap-le │
# │ ---        ┆ ---   ┆ airs       ┆ ngth-mean  ┆ ngth-std   ┆ ngth-q25   ┆ ngth-media ┆ ngth-q75   │
# │ str        ┆ i64   ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ n          ┆ ---        │
# │            ┆       ┆ u32        ┆ f64        ┆ f64        ┆ f64        ┆ ---        ┆ f64        │
# │            ┆       ┆            ┆            ┆            ┆            ┆ f64        ┆            │
# ╞════════════╪═══════╪════════════╪════════════╪════════════╪════════════╪════════════╪════════════╡
# │ minimap2   ┆ 0     ┆ 42         ┆ 19103.7532 ┆ 3645.10128 ┆ 17488.0    ┆ 18478.0    ┆ 20635.0    │
# │            ┆       ┆            ┆ 47         ┆ 7          ┆            ┆            ┆            │
# │ minimap2   ┆ 1     ┆ 1117       ┆ 18608.5004 ┆ 1967.80357 ┆ 17252.0    ┆ 18447.0    ┆ 19803.0    │
# │            ┆       ┆            ┆ 47         ┆ 4          ┆            ┆            ┆            │
# │ ram        ┆ 0     ┆ 1093       ┆ 3821.38226 ┆ 5047.82699 ┆ 891.0      ┆ 1792.0     ┆ 4643.0     │
# │            ┆       ┆            ┆ 9          ┆ 6          ┆            ┆            ┆            │
# │ ram        ┆ 1     ┆ 1097       ┆ 18618.9181 ┆ 1974.24775 ┆ 17253.0    ┆ 18452.0    ┆ 19801.0    │
# │            ┆       ┆            ┆ 65         ┆ 3          ┆            ┆            ┆            │
# │ tb-ram     ┆ 0     ┆ 9          ┆ 10994.6666 ┆ 5896.50279 ┆ 7929.0     ┆ 11296.0    ┆ 15199.0    │
# │            ┆       ┆            ┆ 67         ┆ 8          ┆            ┆            ┆            │
# │ tb-ram     ┆ 1     ┆ 1108       ┆ 18587.2048 ┆ 1972.33286 ┆ 17233.0    ┆ 18428.0    ┆ 19765.0    │
# │            ┆       ┆            ┆ 74         ┆            ┆            ┆            ┆            │
# │ tb-ram-lcs ┆ 0     ┆ 62         ┆ 2503.0     ┆ 5386.85673 ┆ 246.0      ┆ 955.0      ┆ 2784.0     │
# │ k          ┆       ┆            ┆            ┆ 7          ┆            ┆            ┆            │
# │ tb-ram-lcs ┆ 1     ┆ 1055       ┆ 18626.8635 ┆ 1977.92111 ┆ 17233.0    ┆ 18458.0    ┆ 19810.0    │
# │ k          ┆       ┆            ┆ 07         ┆ 6          ┆            ┆            ┆            │
# └────────────┴───────┴────────────┴────────────┴────────────┴────────────┴────────────┴────────────┘

# %%
g = sns.FacetGrid(
    df_overlaps.to_pandas(),
    row="label",
    col="source",
)
g.map_dataframe(sns.scatterplot, x="overlap-length", y="n-residue-matches")

# %%
df_tb_ram_lcskpp_sample = (
    df_tb_ram_lcskpp.with_columns(
        pl.max_horizontal(
            pl.col("query-end") - pl.col("query-start"),
            pl.col("target-end") - pl.col("target-start"),
        ).alias("overlap-length")
    )
    .with_columns(
        (pl.col("n-residue-matches") / pl.col("overlap-length")).alias("matches-normed")
    )
    .sort(by="n-residue-matches", descending=True)
    .group_by(
        by=["query-name", "target-name"],
        maintain_order=True,
    )
    .head(5)
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_698971/110031965.py in ?()
#       8     .with_columns(
#       9         (pl.col("n-residue-matches") / pl.col("overlap-length")).alias("matches-normed")
#      10     )
#      11     .sort(by="n-residue-matches", descending=True)
# ---> 12     .group_by(
#      13         by=["query-name", "target-name"],
#      14         maintain_order=True,
#      15     )
#
# ~/dev/tb-ram/venv/lib/python3.11/site-packages/polars/dataframe/frame.py in ?(self, maintain_order, *by, **named_by)
#    5848                     f"    group_by(by={value!r})\n"
#    5849                     "then you probably want to use this instead:\n"
#    5850                     f"    group_by({value!r})"
#    5851                 )
# -> 5852                 raise TypeError(msg)
#    5853         return GroupBy(self, *by, **named_by, maintain_order=maintain_order)
#
# TypeError: Expected Polars expression or object convertible to one, got <class 'list'>.
#
# Hint: if you tried
#     group_by(by=['query-name', 'target-name'])
# then you probably want to use this instead:
#     group_by(['query-name', 'target-name'])

# %%
g = sns.FacetGrid(df_tb_ram_lcskpp_sample.to_pandas(), col="label")
g.map_dataframe(
    sns.scatterplot,
    x="overlap-length",
    y="matches-normed",
    hue="label",
)
